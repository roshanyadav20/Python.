# %% [markdown]
# Input Function in Python

# %% [markdown]
# Input function always reads input value as a string

# %%
a = input()
print(a)
# Out:
# madhav

# %%
a = input()
print(a + a)
# Out:
# madhavmadhav

# %%
a = input()
print(int(a) + int(a))
# Out:
# 6

# %%
name = input("Enter your name: ")
print(f"Welcome {name} to the placement")
# Out:
# Welcome roshan to the placement

# %%
age = input("Enter your age: ")
print(f"Ohh you're just {age}!")
print(f"Ohh you're just {int(age)+1}!")
# Out:
# Ohh you're just 22!
# Ohh you're just 23!

# %%
# input from user to add two number and print result
x = input("Enter first number: ")
y = input("Enter second number: ")
print(f"Sum of {x} & {y} is {int(x) + int(y)}")
# Out:
# Sum of 1 & 2 is 3
