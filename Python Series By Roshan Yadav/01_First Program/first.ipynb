# %% [markdown]
# Basics

# %%
#write a program to Hello World.
print("Hello World!")
# Out:
# Hello World!

# %%
# This is a variable
a = 5
print(a)
# Out:
# 5

# %%
# This is a variable 
Instructor = "Roshan Yadav"
print("Python by", Instructor)
# Out:
# Python by Roshan Yadav

# %%
# Python as a calculator
print(5 + 3)
# Out:
# 8

# %%
# String per koi bhi mathmatical operation perform nhi hota hai. jaisa hai waisa hi rhega.
print("5 + 3")
# Out:
# 5 + 3

# %%
print("Python by", Instructor, sep='-')
# Out:
# Python by-Roshan Yadav

# %%
print("Python by ", Instructor, sep='--')
# Out:
# Python by --Roshan Yadav

# %%
b = 10
c = 20
print(b + c)
# Out:
# 30
